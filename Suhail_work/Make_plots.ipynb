# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
from scipy import signal
from astropy.io import fits
from sklearn.decomposition import FastICA, PCA
from scipy.stats import pearsonr as pear
from PIL import Image, ImageDraw
import matplotlib.image as mpimg

# %%
#load images
image1 = mpimg.imread('images/Variance_noise100.png')
image2 = mpimg.imread('images/Variance_noise1000.png')
image3 = mpimg.imread('images/Variance_noise10000.png')

# %%
fig, axes = plt.subplots(3,1,figsize = (20,20))

#display images

axes[0].imshow(image1)
axes[0].set_title('100 hours observation')

axes[1].imshow(image2)
axes[1].set_title('1000 hours observation')

axes[2].imshow(image3)
axes[2].set_title('10000 hours observation')

for ax in axes:
    ax.axis('off')
    
plt.tight_layout()
plt.savefig('images/observation_noise.png')
plt.show()

# %%
#load images of power spectrum 2D
image2 = mpimg.imread('images/Extra galactic 2D power spectrum, frequency =128.2MHZ.png')
image3 = mpimg.imread('images/free free emission 2D power spectrum, frequency =128.2MHZ.png')
image4 = mpimg.imread('images/synchrotron 2D power spectrum, frequency =128.2MHZ.png')
image5 = mpimg.imread('images/all foregrounds 2D power spectrum, frequency =160.6MHZ.png')
image6 = mpimg.imread('images/21cmsignal 2D power spectrum, frequency =160.6MHZ.png')

# %%
fig, axes = plt.subplots(3,1,figsize = (20,20))

#display images

axes[0].imshow(image2)


axes[1].imshow(image3)


axes[2].imshow(image4)


for ax in axes:
    ax.axis('off')
    
plt.tight_layout()
plt.savefig('images/foregrounds_2Dpowerspectrum.png')
plt.show()

# %%
fig, axes = plt.subplots(2,1,figsize = (10,10))

#display images

axes[0].imshow(image5)


axes[1].imshow(image6)


for ax in axes:
    ax.axis('off')
    
plt.tight_layout()
plt.savefig('images/21cmsignal and all foregrounds power spectrum.png')
plt.show()

# %%
#1d power spectrum images
#load images
image1 = mpimg.imread('images/powerspectrum for lightcone.png')
image2 = mpimg.imread('images/powerspectrum for foregrounds.png')
image3 = mpimg.imread('images/powerspectrum for noise.png')
image4 = mpimg.imread('images/powerspectrum for residual.png')

# %%
fig, axes = plt.subplots(2,2,figsize = (10,10))

#display images

axes[0,0].imshow(image1)
axes[0,0].axis('off')

axes[0,1].imshow(image2)
axes[0,1].axis('off')

axes[1,0].imshow(image3)
axes[1,0].axis('off')

axes[1,1].imshow(image4)
axes[1,1].axis('off')

    
plt.tight_layout()
plt.savefig('images/power_spectrum_subplots.png')
plt.show()
